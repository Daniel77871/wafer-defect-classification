# %% [markdown]
# # WM-811K EDA
#
# This notebook reproduces the Phase 1 EDA artifacts by calling project code. Place `LSWMD.pkl` in `data/raw/` before running.

# %%
from pathlib import Path
import os

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
os.chdir(PROJECT_ROOT)

from IPython.display import Image, Markdown, display
from src.data.load import compute_wafer_stats, get_labeled_subset, load_wm811k
from src.evaluation.eda import run_all_eda

# %%
run_all_eda(
    raw_path=PROJECT_ROOT / "data/raw/LSWMD.pkl",
    output_dir=PROJECT_ROOT / "results/figures/eda",
    seed=42,
)

# %%
display(Markdown((PROJECT_ROOT / "results/figures/eda/eda_takeaways.md").read_text()))

# %% [markdown]
# ## 01 Class Distribution Full

# %%
display(Image(filename=PROJECT_ROOT / "results/figures/eda/01_class_distribution_full.png"))

# %% [markdown]
# ## 02 Class Distribution Defects Only

# %%
display(Image(filename=PROJECT_ROOT / "results/figures/eda/02_class_distribution_defects_only.png"))

# %% [markdown]
# ## 03 Wafer Size Distribution

# %%
display(Image(filename=PROJECT_ROOT / "results/figures/eda/03_wafer_size_distribution.png"))

# %% [markdown]
# ## 04 Defect Density by Class

# %%
display(Image(filename=PROJECT_ROOT / "results/figures/eda/04_defect_density_by_class.png"))

# %% [markdown]
# ## 05 Mean Image per Class

# %%
display(Image(filename=PROJECT_ROOT / "results/figures/eda/05_mean_image_per_class.png"))

# %% [markdown]
# ## 06 Inter-Class Similarity

# %%
display(Image(filename=PROJECT_ROOT / "results/figures/eda/06_inter_class_similarity.png"))

# %% [markdown]
# ## 07 UMAP Embedding

# %%
display(Image(filename=PROJECT_ROOT / "results/figures/eda/07_umap_embedding.png"))

# %% [markdown]
# ## 08 Label Noise in `none`

# %%
display(Image(filename=PROJECT_ROOT / "results/figures/eda/08_label_noise_in_none.png"))
display(Image(filename=PROJECT_ROOT / "results/figures/eda/08b_suspicious_none_examples.png"))
